# %% [markdown]
# ##MolSSI workshop
# ###August 8, 2019

# %%
cms-workshop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b495221f2734> in <module>
# ----> 1 cms-workshop
#
# NameError: name 'cms' is not defined

# %%
3+7
# Out:
# 10

# %%
#variable_name = value
deltaH = -541.5 #kJ/mol
deltaS = 10.4   #kJ/mol
temperatue = 298 #K
deltaG = deltaH - (temperature*deltaS)
print deltaG
# Out:
#   File "<ipython-input-3-242e85000007>", line 6
#     print deltaG
#                ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(deltaG)?

# %%
#variable_name = value
deltaH = -541.5 #kJ/mol
deltaS = 10.4   #kJ/mol
tempe = 298 #K
deltaG = deltaH - (temp*deltaS)
print (deltaG)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-634526c23526> in <module>
#       3 deltaS = 10.4   #kJ/mol
#       4 temperatue = 298 #K
# ----> 5 deltaG = deltaH - (temperature*deltaS)
#       6 print (deltaG)
#
# NameError: name 'temperature' is not defined

# %%
#variable_name = value
deltaH = -541.5 #kJ/mol
deltaS = 10.4   #kJ/mol
tempe = 298 #K
deltaG = deltaH - (temp*deltaS)
print (deltaG)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-86964c594cfb> in <module>
#       3 deltaS = 10.4   #kJ/mol
#       4 tempe = 298 #K
# ----> 5 deltaG = deltaH - (temp*deltaS)
#       6 print (deltaG)
#
# NameError: name 'temp' is not defined

# %%
#variable_name = value
deltaH = -541.5 #kJ/mol
deltaS = 10.4   #kJ/mol
temp = 298 #K
deltaG = deltaH - (temp*deltaS)
print (deltaG)
# Out:
# -3640.7000000000003

# %%
deltaG*100
# Out:
# -364070.0

# %%
print (deltaG)
# Out:
# -3640.7000000000003

# %%
type (deltaG)
# Out:
# float

# %%
deltaG_string = str(deltaG)
type (deltaG_string)
# Out:
# str

# %%
deltaG_string*10
# Out:
# '-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003'

# %%
energy_kcal = [-13.4, -2.7, 5.4, 42.1]
print(energy_kcal[1])
# Out:
# -2.7

# %%
energy_cal = energy_kcal[1] *1000
print(energy_cal)
# Out:
# -2700.0

# %% [markdown]
# #Taking a slice

# %% [markdown]
# #Taking a slice

# %%
#new_list = old_list[start:end] # upto But not include the end
short_list = energy_kcal[0:2]
print(short_list)
# Out:
# [-13.4, -2.7]

# %%
len(energy_kcal)
len(short_list)
# Out:
# 2

# %%
slice1 = energy_kcal[1:]
slice2 = energy_kcal[:3]
print('slice 1 =', slice1)
print('slice 2 =', slice2)
# Out:
# slice 1 = [-2.7, 5.4, 42.1]
# slice 2 = [-13.4, -2.7, 5.4]

# %%
#for variable in list_name:
#    do things with variable

# %%
for number in energy_kcal:
    kJ = number*4.184
    print(kJ)
# Out:
# -56.0656
# -11.296800000000001
# 22.593600000000002
# 176.1464

# %%
#list_name.append(new_thing)

# %%
for number in energy_kcal:
    kJ = number*4.184
    energy_kJ.append(kJ)
    print(energy_kJ)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-c6fd3d04f997> in <module>
#       1 for number in energy_kcal:
#       2     kJ = number*4.184
# ----> 3     energy_kJ.append(kJ)
#       4     print(energy_kJ)
#
# NameError: name 'energy_kJ' is not defined

# %%
for number in energy_kcal:
    kJ = number*4.184
    energy_kJs.append(kJ)
    print(energy_kJs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-12d6d3a3a5d1> in <module>
#       1 for number in energy_kcal:
#       2     kJ = number*4.184
# ----> 3     energy_kJs.append(kJ)
#       4     print(energy_kJs)
#
# NameError: name 'energy_kJs' is not defined

# %%
energy_kJs = []
for number in energy_kcal:
    kJ = number*4.184
    energy_kJs.append(kJ)
    print(energy_kJs)
# Out:
# [-56.0656]
# [-56.0656, -11.296800000000001]
# [-56.0656, -11.296800000000001, 22.593600000000002]
# [-56.0656, -11.296800000000001, 22.593600000000002, 176.1464]

# %%
energy_kJs = []
for number in energy_kcal:
    kJ = number*4.184
    energy_kJs.append(kJ)
print(energy_kJs)
# Out:
# [-56.0656, -11.296800000000001, 22.593600000000002, 176.1464]

# %%
negative_energy = []
for number in energy_kJs:
    if number < 0:
        negative_energy.append(number)
print(negative_energy)
# Out:
# [-56.0656, -11.296800000000001]

# %%
negative_energy = []
for number in energy_kJs:
    if number < 0:
        negative_energy.append(number)
        
    else:
        positive_energy.append(number)
        
print(negative_energy)
print(positive_energy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-3c8fd3bd0bbc> in <module>
#       5
#       6     else:
# ----> 7         positive_energy.append(number)
#       8
#       9 print(negative_energy)
#
# NameError: name 'positive_energy' is not defined

# %%
negative_energy = []
positive_energy = []

for number in energy_kJs:
    if number < 0:
        negative_energy.append(number)
        
    else:
        positive_energy.append(number)
        
print(negative_energy)
print(positive_energy)
# Out:
# [-56.0656, -11.296800000000001]
# [22.593600000000002, 176.1464]

# %%
len(negative_energy)
# Out:
# 2

# %%
distance_file = os.path.join('data', 'distance_data_headers.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-cc25f01eca50> in <module>
# ----> 1 distance_file = os.path.join('data', 'distance_data_headers.csv')
#
# NameError: name 'os' is not defined

# %%
import os

# %%
distance_file = os.path.join('data', 'distance_data_headers.csv')

# %%
distances = numpy.genfromtxt(fname=distance_file, delimiter=',', dtype='unicode')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-c07f983f647e> in <module>
# ----> 1 distances = numpy.genfromtxt(fname=distance_file, delimiter=',', dtype='unicode')
#
# NameError: name 'numpy' is not defined

# %%
import numpy as np

# %%
distances = np.genfromtxt(fname=distance_file, delimiter=',', dtype='unicode')

# %%
headers = distances[0]

# %%
print(headers)
# Out:
# ['Frame' 'THR4_ATP' 'THR4_ASP' 'TYR6_ATP' 'TYR6_ASP']

# %%
data = distances[1:]

# %%
print(data)
# Out:
# [['1' '8.9542' '5.8024' '11.5478' '9.9557']
#  ['2' '8.6181' '6.0942' '13.9594' '11.6945']
#  ['3' '9.0066' '6.0637' '13.0924' '11.3043']
#  ...
#  ['9998' '8.6625' '7.7306' '9.5469' '10.3063']
#  ['9999' '9.2456' '7.8886' '9.8151' '10.7564']
#  ['10000' '8.8135' '7.917' '9.9517' '10.7848']]

# %%
data = data.astype(np.float)

# %%
import matplotlib.pyplot

# %%
matplotlib.pyplot.figure()     #This initializes a new figure

# %%
matplotlib.pyplot.plot(data[:,1])

# %%
print(distances)
# Out:
# [['Frame' 'THR4_ATP' 'THR4_ASP' 'TYR6_ATP' 'TYR6_ASP']
#  ['1' '8.9542' '5.8024' '11.5478' '9.9557']
#  ['2' '8.6181' '6.0942' '13.9594' '11.6945']
#  ...
#  ['9998' '8.6625' '7.7306' '9.5469' '10.3063']
#  ['9999' '9.2456' '7.8886' '9.8151' '10.7564']
#  ['10000' '8.8135' '7.917' '9.9517' '10.7848']]

# %%
matplotlib.pyplot.plot(data[:,2])

# %%
matplotlib.pyplot.plot(data[1:,2])

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()

# %%
plt.plot(data[:,1])

# %%
sample = headers[1]

# %%
print(sample)
# Out:
# THR4_ATP

# %%
plt.figure()

# %%
plt.xlabel('Simulation Frame')
# Out:
# Text(0.5, 0, 'Simulation Frame')

# %%
plt.ylabel('Distance (angstrom)')
# Out:
# Text(0, 0.5, 'Distance (angstrom)')

# %%
fig_1 = plt.plot(data[:,1], label=sample)

# %%
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
fig_1 = plt.plot(data[:,1], label=sample)

# %%
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.savefig(F'{sample}.png')

# %%
plt.figure()
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstrom)')
plt.plot(data[:,1], label=headers[1])
plt.plot(data[:,2], label=headers[2])
plt.legend()
plt.savefig('two_samples.png')

# %%
len(headers)
# Out:
# 5

# %%
for col in range(1, len(headers)):
    fig = plt.plot(data[:,col], label=headers[col])
    plt.legend()

plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstrom)')
plt.savefig('all_samples.png')

# %%
plt.plot(data[:,1], label=headers[1])

# %%
plt.figure()
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstrom)')
plt.plot(data[:,1], label=headers[1])

# %%
plt.figure()
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstrom)')
plt.plot(data[:,1], label=headers[1])
plt.plot(data[:,2], label=headers[2])
plt.legend()
plt.savefig('two_samples.png')

# %%
plt.figure()

# %%
plt.xlabel('Frame')
# Out:
# Text(0.5, 0, 'Frame')

# %%
plt.ylabel('Distance')
# Out:
# Text(0, 0.5, 'Distance')

# %%
plt.plot(data[:1], label=headers[1])

# %%
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot(data[:1], label=headers[1])

# %%
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure()
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstrom)')
plt.plot(data[:,1], label=headers[1])
plt.legend()
plt.savefig('two_samples.png')

# %%
plt.figure()
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstrom)')
plt.plot(data[:,1], label=headers[1])

# %%
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
len(headers)
# Out:
# 5

# %%
for col in range(1, len(headers)):
    print(col)
# Out:
# 1
# 2
# 3
# 4

# %%
fig = plt.plot(label=headers[col])

# %%
for col in range(1, len(headers)):
    plt.plot(data[:,col], label=headers[col])
    plt.legend()

# %%
for col in range(1, len(headers)):
    plt.plot(data[:,col], label=headers[col], '--')
    plt.legend()
# Out:
#   File "<ipython-input-78-f2bb63132615>", line 2
#     plt.plot(data[:,col], label=headers[col], '--')
#                                              ^
# SyntaxError: positional argument follows keyword argument

# %%
for col in range(1, len(headers)):
    plt.plot(data[:,col], '--', label=headers[col])
    plt.legend()

# %%
for col in range(1, len(headers)):
    plt.plot(data[:,col], 'o', label=headers[col])
    plt.legend()

# %%
for col in range(1, len(headers)):
    plt.plot(data[:,col], ' - ', label=headers[col])
    plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-4c0d7370f831> in <module>
#       1 for col in range(1, len(headers)):
# ----> 2     plt.plot(data[:,col], ' - ', label=headers[col])
#       3     plt.legend()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# ...

# %%
for col in range(1, len(headers)):
    plt.plot(data[:,col], '--', label=headers[col])
    plt.legend()

# %%
for col in range(1, len(headers)):
    plt.plot(data[1:100:,col], '--', label=headers[col])
    plt.legend()

# %%
for col in range(1, len(headers)):
    plt.plot(data[1:100:,col], '--o', label=headers[col])
    plt.legend()

# %%
for col in range(1, len(headers)):
    plt.plot(data[1:100:,col], '--', label=headers[col])
    plt.legend()

# %%
for col in range(1, len(headers)):
    plt.plot(data[1:100:,2], '--', label=headers[col])
    plt.legend()

# %%
for col in range(1, len(headers)):
    plt.plot(data[1:100:,col], '--', label=headers[col])
    plt.legend()

# %%
plt.xlabel('Frame')
plt.ylabel('Distance')
for col in range(1, len(headers)):
    plt.plot(data[1:100:,col], '--', label=headers[col])
    plt.legend()

# %%
plt.xlabel('Frame')
plt.ylabel('Distance')
for col in range(1, len(headers)):
    plt.plot(data[1:101:,col], '--', label=headers[col])
    plt.legend()

# %%
for col in range(1, len(headers)):
# Out:
#   File "<ipython-input-90-b2c7eff449a4>", line 1
#     for col in range(1, len(headers)):
#                                       ^
# SyntaxError: unexpected EOF while parsing

# %%
pwd
# Out:
# '/Users/nd372281/Desktop/cms-workshop'

# %%
ls
# Out:
# THR4_ATP.png     all_samples.png  data.zip
# Untitled.ipynb   data/            two_samples.png

# %%
ls data
# Out:
# benzene.xyz*               outfiles/
# buckminsterfullerene.xyz*  sapt.out*
# distance_data_headers.csv* water.xyz*

# %%
ls data/outfiles/
# Out:
# butanol.out*  ethanol.out*  hexanol.out*  nonanol.out*  pentanol.out*
# decanol.out*  heptanol.out* methanol.out* octanol.out*  propanol.out*

# %%
ethano_file = os.path.join('data', outfiles', ethano.out')
print(ethano_file)
# Out:
#   File "<ipython-input-95-42bad5eba5a9>", line 1
#     ethano_file = os.path.join('data', outfiles', ethano.out')
#                                                             ^
# SyntaxError: invalid syntax

# %%
ethano_file = os.path.join('data', 'outfiles', ethano.out')
print(ethano_file)
# Out:
#   File "<ipython-input-96-d1b1257e05aa>", line 1
#     ethano_file = os.path.join('data', 'outfiles', ethano.out')
#                                                                ^
# SyntaxError: EOL while scanning string literal

# %%
ethano_file = os.path.join('data', 'outfiles', 'ethanol.out')
print(ethano_file)
# Out:
# data/outfiles/ethanol.out

# %%
ethanol_file = os.path.join('data', 'outfiles', 'ethanol.out')
print(ethano_file)
# Out:
# data/outfiles/ethanol.out

# %%
outfile = open(ethanol_file, 'r')

# %%
data = outfile.readlines()

# %%
print(data)
# Out:
# ['\n', '    -----------------------------------------------------------------------\n', '          Psi4: An Open-Source Ab Initio Electronic Structure Package\n', '                               Psi4 1.1 release\n', '\n', '                         Git: Rev {HEAD} add49b9 \n', '\n', '\n', '    R. M. Parrish, L. A. Burns, D. G. A. Smith, A. C. Simmonett,\n', '    A. E. DePrince III, E. G. Hohenstein, U. Bozkaya, A. Yu. Sokolov,\n', '    R. Di Remigio, R. M. Richard, J. F. Gonthier, A. M. James,\n', '    H. R. McAlexander, A. Kumar, M. Saitow, X. Wang, B. P. Pritchard,\n', '    P. Verma, H. F. Schaefer III, K. Patkowski, R. A. King, E. F. Valeev,\n', '    F. A. Evangelista, J. M. Turney, T. D. Crawford, and C. D. Sherrill,\n', '    J. Chem. Theory Comput. in press (2017).\n', '    (doi: 10.1021/acs.jctc.7b00174)\n', '\n', '    -----------------------------------------------------------------------\n', '\n', '\n', '    Psi4 started on: Tuesday, 27 June 2017 12:10PM\n', '\n', '    Process
# ...

# %%
outfile.close()

# %%
for line in data:
    print(line)
# Out:
#     -----------------------------------------------------------------------
#
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#
#                                Psi4 1.1 release
#
#
#
#                          Git: Rev {HEAD} add49b9
#
#
#
#
#
#     R. M. Parrish, L. A. Burns, D. G. A. Smith, A. C. Simmonett,
#
#     A. E. DePrince III, E. G. Hohenstein, U. Bozkaya, A. Yu. Sokolov,
#
#     R. Di Remigio, R. M. Richard, J. F. Gonthier, A. M. James,
#
#     H. R. McAlexander, A. Kumar, M. Saitow, X. Wang, B. P. Pritchard,
#
#     P. Verma, H. F. Schaefer III, K. Patkowski, R. A. King, E. F. Valeev,
#
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, and C. D. Sherrill,
#
#     J. Chem. Theory Comput. in press (2017).
#
#     (doi: 10.1021/acs.jctc.7b00174)
#
#
#
#     -----------------------------------------------------------------------
#
#
#
#
#
#     Psi4 started on: Tuesday, 27 June 2017 12:10PM
#
#
#
#     Process ID:  10591
#
# ...

# %%
for line in data:
    if 'Final Energy' in line:
        energy_line = line
        print(energy_line)
# Out:
#   @DF-RHF Final Energy:  -154.09130176573018

# %%
energy_line.split(':')
# Out:
# ['  @DF-RHF Final Energy', '  -154.09130176573018\n']

# %%
for linenum, line in enumerate(data):
    if 'Center' in line:
        print (linenum)
        print (line)
# Out:
# 77
#        Center              X                  Y                   Z               Mass

# %%
for linenum, line in data:
    if 'Center' in line:
        print (linenum)
        print (line)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-062e03ec8ef0> in <module>
# ----> 1 for linenum, line in data:
#       2     if 'Center' in line:
#       3         print (linenum)
#       4         print (line)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
for linenum, line in data:
    if 'Center' in line:
        print (linenum)
        print (line)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-062e03ec8ef0> in <module>
# ----> 1 for linenum, line in data:
#       2     if 'Center' in line:
#       3         print (linenum)
#       4         print (line)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
for linenum, line in enumerate(data):
    if 'Center' in line:
        print (linenum)
        print (line)
# Out:
# 77
#        Center              X                  Y                   Z               Mass

# %%
print(data[2])
# Out:
#           Psi4: An Open-Source Ab Initio Electronic Structure Package

# %%
print(data[80])
# Out:
#            C          0.253854764252     1.255132047666    -0.179502449480    12.000000000000

# %%
#import library_name
#output = library_name.function_name(input)

# %%
pwd
# Out:
# '/Users/nd372281/Desktop/cms-workshop'

# %%
ls
# Out:
# THR4_ATP.png     all_samples.png  data.zip
# Untitled.ipynb   data/            two_samples.png

# %%
import os
outfile_dir = os.path.join('data', 'outfiles', 'water.xyz')

# %%
import os
outfile_dir = os.path.join('data', 'outfiles')

# %%
print(outfile_dir)
# Out:
# data/outfiles

# %%
file_location = os.path.join(outfile_dir,'*.out')

# %%
print(file_location)
# Out:
# data/outfiles/*.out

# %%
import glob
filenames = glob.glob(file_location)

# %%
print(filenames)
# Out:
# ['data/outfiles/butanol.out', 'data/outfiles/decanol.out', 'data/outfiles/ethanol.out', 'data/outfiles/heptanol.out', 'data/outfiles/hexanol.out', 'data/outfiles/methanol.out', 'data/outfiles/nonanol.out', 'data/outfiles/octanol.out', 'data/outfiles/pentanol.out', 'data/outfiles/propanol.out']

# %%
for f in filenames:
    outfile = open(f, 'r')
    data = outfile.readlines()
    outfile.close()
    for line in data:
        if 'Final Energy' in line:
            energy_line = line
            words = energy_line.split()
            energy = float(words[3])
            print(energy)
# Out:
# -232.1655798347283
# -466.3836241400086
# -154.09130176573018
# -349.27397687072676
# -310.2385332251633
# -115.04800861868374
# -427.3465180082815
# -388.3110864554743
# -271.20138119895074
# -193.12836249728798

# %%
first_file = filenames[0]
print(first_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-123-395f5c69a57c> in <module>
# ----> 1 first_file = filename[0]
#       2 print(first_file)
#
# NameError: name 'filename' is not defined

# %%
first_file = filenames[0]
print(first_file)
# Out:
# data/outfiles/butanol.out

# %%
file_name = os.path.basename(first_file)
print(first_file)
# Out:
# data/outfiles/butanol.out

# %%
molecular_name = filename.split()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-126-16d01bf20946> in <module>
# ----> 1 molecular_name = filename.split()
#
# NameError: name 'filename' is not defined

# %%
split_filename = filename.split('.')
print(split_filename)
molecular_name = split_filename[0]
print(molecular_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-127-99667281eb43> in <module>
# ----> 1 split_filename = filename.split('.')
#       2 print(split_filename)
#       3 molecular_name = split_filename[0]
#       4 print(molecular_name)
#
# NameError: name 'filename' is not defined

# %%
split_filename = filename.split('.')
print(split_filename)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-128-b472a4a2b16f> in <module>
# ----> 1 split_filename = filename.split('.')
#       2 print(split_filename)
#
# NameError: name 'filename' is not defined

# %%
split_filename = filenames.split('.')
print(split_filename)
molecular_name = split_filename[0]
print(molecular_name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-129-cae6b8caefe7> in <module>
# ----> 1 split_filename = filenames.split('.')
#       2 print(split_filename)
#       3 molecular_name = split_filename[0]
#       4 print(molecular_name)
#
# AttributeError: 'list' object has no attribute 'split'

# %%
    split_filname = file_name.split('.')
    molecule_name = split_filename[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-130-9ebba174ab3b> in <module>
#       1 split_filname = file_name.split('.')
# ----> 2 molecule_name = split_filename[0]
#
# NameError: name 'split_filename' is not defined

# %%
split_filname = file_name.split('.')

# %%
molecule_name = split_filename[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-132-34f3f40557d7> in <module>
# ----> 1 molecule_name = split_filename[0]
#
# NameError: name 'split_filename' is not defined

# %%
split_filename = first_file.split()

# %%
split_filename = first_file.split('.')

# %%
print(split_filename)
# Out:
# ['data/outfiles/butanol', 'out']

# %%
molecule_name = split_filename[0]
print(molecule_name)
# Out:
# data/outfiles/butanol

# %%
for f in filenames:
    outfile = open(f, 'r')
    filename = os.path.basename(f)
    data = outfile.readlines()
    outfile.close()
    for line in data:
        if 'Final Energy' in line:
            energy_line = line
            words = energy_line.split()
            energy = float(words[3])
            datafile.write(F'{molecule_name} \t {energy} \n')
    datafile.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-f147656679be> in <module>
#       8             words = energy_line.split()
#       9             energy = float(words[3])
# ---> 10             datafile.write(F'{molecule_name} \t {energy} \n')
#      11     datafile.close()
#
# NameError: name 'datafile' is not defined

# %%
for f in filenames:
    outfile = open(f, 'r')
    filename = os.path.basename(f)
    data = outfile.readlines()
    outfile.close()
    for line in data:
        if 'Final Energy' in line:
            energy_line = line
            words = energy_line.split()
            energy = float(words[3])
            datafile.write(F'{molecule_name} \t {energy} \n')
    datafile.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-138-5f82ef684852> in <module>
#       9             words = energy_line.split()
#      10             energy = float(words[3])
# ---> 11             datafile.write(F'{molecule_name} \t {energy} \n')
#      12     datafile.close()
#
# NameError: name 'datafile' is not defined

# %%
for f in filenames:
    outfile = open(f, 'r')
    filename = os.path.basename(f)
    split_filename = file_name.split('.')
    molecule_name = split_filename[0]
    data = outfile.readlines()
    outfile.close()
    for line in data:
        if 'Final Energy' in line:
            energy_line = line
            words = energy_line.split()
            energy = float(words[3])
            print(molecule_name, energy)
# Out:
# butanol -232.1655798347283
# butanol -466.3836241400086
# butanol -154.09130176573018
# butanol -349.27397687072676
# butanol -310.2385332251633
# butanol -115.04800861868374
# butanol -427.3465180082815
# butanol -388.3110864554743
# butanol -271.20138119895074
# butanol -193.12836249728798

# %%
datafile = open('energies.txt','w+')  #This opens the file for writing
for f in filenames:
    outfile = open(f, 'r')
    filename = os.path.basename(f)
    split_filename = file_name.split('.')
    molecule_name = split_filename[0]
    data = outfile.readlines()
    outfile.close()
    for line in data:
        if 'Final Energy' in line:
            energy_line = line
            words = energy_line.split()
            energy = float(words[3])
            print(molecule_name, energy)
            datafile.write(F'{molecule_name} \t {energy} \n')
datafile.close()
